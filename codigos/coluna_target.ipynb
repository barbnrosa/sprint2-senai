# %%
import pandas as pd

# %%
df_pj = pd.read_csv('../dados/PJ_tratados.csv')

# %%
df_pj.drop(columns='Unnamed: 0', inplace=True)

# %%
df_pj.head()
# Out:
#   ID Cliente Linha de Ação        Produto GPOM Data de Venda    Cidade  \
# 0        550      EDUCACAO  EDUCACAO EXECUTIVA    2021-07-29  CURITIBA
# 1        550      EDUCACAO  EDUCACAO EXECUTIVA    2022-12-01  CURITIBA
# 2        550      EDUCACAO  EDUCACAO EXECUTIVA    2022-12-15  CURITIBA
# 3        367      EDUCACAO  EDUCACAO EXECUTIVA    2023-10-16  CURITIBA
# 4        550      EDUCACAO           GRADUACAO    2022-11-24  CURITIBA
#
#                                    Classe de Serviço Micro_regiao   Porte  \
# 0          PROGRAMAS NACIONAIS DE EDUCACAO EXECUTIVA     CURITIBA  GRANDE
# 1  CURSOS E PROGRAMAS NACIONAIS EM GESTAO EMPRESA...     CURITIBA  GRANDE
# 2  CURSOS E PROGRAMAS NACIONAIS EM GESTAO EMPRESA...     CURITIBA  GRANDE
# 3  CURSOS E PROGRAMAS NACIONAIS EM GESTAO EMPRESA...     CURITIBA   MÉDIA
# 4                  GRADUACAO TECNOLOGICA A DISTANCIA     CURITIBA  GRANDE
#
#   Estado Fim de Vigência Tipo Pessoa    Setor IBGE Área de Atuação  \
# ...

# %%
df_pj['Produto GPOM'].value_counts()
# Out:
# Produto GPOM
# PROGRAMAS DE SAUDE E SEGURANCA                              15771
# AUXILIO DIAGNOSTICO                                         12540
# CONSULTA CLINICA OCUPACIONAL                                10029
# APERFEICOAMENTO PROFISSIONAL                                 6628
# VACINACAO                                                    4637
#                                                             ...
# TELEATENDIMENTO EM SAUDE                                        1
# EDUCACAO CONTINUADA EM EDUCACAO                                 1
# APERFEICOAMENTO/ ESPECIALIZACAO PROFISSIONAL A DISTANCIA        1
# TECNICO DE NIVEL MEDIO A DISTANCIA                              1
# CONSULTORIA EM LONGEVIDADE                                      1
# Name: count, Length: 87, dtype: int64

# %%
df_pj['Target'] = df_pj['Produto GPOM'].apply(lambda x: 1 if x == 'PROGRAMAS DE SAUDE E SEGURANCA' else 0)

# %%
df_pj.head()
# Out:
#   ID Cliente Linha de Ação        Produto GPOM Data de Venda    Cidade  \
# 0        550      EDUCACAO  EDUCACAO EXECUTIVA    2021-07-29  CURITIBA
# 1        550      EDUCACAO  EDUCACAO EXECUTIVA    2022-12-01  CURITIBA
# 2        550      EDUCACAO  EDUCACAO EXECUTIVA    2022-12-15  CURITIBA
# 3        367      EDUCACAO  EDUCACAO EXECUTIVA    2023-10-16  CURITIBA
# 4        550      EDUCACAO           GRADUACAO    2022-11-24  CURITIBA
#
#                                    Classe de Serviço Micro_regiao   Porte  \
# 0          PROGRAMAS NACIONAIS DE EDUCACAO EXECUTIVA     CURITIBA  GRANDE
# 1  CURSOS E PROGRAMAS NACIONAIS EM GESTAO EMPRESA...     CURITIBA  GRANDE
# 2  CURSOS E PROGRAMAS NACIONAIS EM GESTAO EMPRESA...     CURITIBA  GRANDE
# 3  CURSOS E PROGRAMAS NACIONAIS EM GESTAO EMPRESA...     CURITIBA   MÉDIA
# 4                  GRADUACAO TECNOLOGICA A DISTANCIA     CURITIBA  GRANDE
#
#   Estado Fim de Vigência  ...    Setor IBGE Área de Atuação  \
# ...

# %%
df_pj[df_pj['Produto GPOM'] == 'PROGRAMAS DE SAUDE E SEGURANCA']
# Out:
#                                  ID Cliente                   Linha de Ação  \
# 2160   053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 2161   053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 2172   06327402-6092-E211-AF7A-00155D726C01  SAUDE E SEGURANCA NA INDUSTRIA
# 2173   06327402-6092-E211-AF7A-00155D726C01  SAUDE E SEGURANCA NA INDUSTRIA
# 2192   07C1ABF1-61EB-ED11-A7C6-000D3AC1A7DE  SAUDE E SEGURANCA NA INDUSTRIA
# ...                                     ...                             ...
# 79047  C8226A39-389D-E711-8114-2C59E53AD368  SAUDE E SEGURANCA NA INDUSTRIA
# 79051  5578CB17-176A-EB11-A812-00224835D13E  SAUDE E SEGURANCA NA INDUSTRIA
# 79052  5578CB17-176A-EB11-A812-00224835D13E  SAUDE E SEGURANCA NA INDUSTRIA
# 79057  EC55046D-A369-E311-A9D8-00155D726C01  SAUDE E SEGURANCA NA INDUSTRIA
# 79058  EC55046D-A369-E311-A9D8-00155D726C01  SAUDE E SEGURANCA NA INDUSTRIA
#
# ...

# %%
df_pj[df_pj['ID Cliente'] == '053EC310-A41C-ED11-B83E-002248DE66D4']
# Out:
#                                 ID Cliente                   Linha de Ação  \
# 468   053EC310-A41C-ED11-B83E-002248DE66D4                        EDUCACAO
# 2156  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 2157  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 2158  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 2159  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 2160  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 2161  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 4303  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
# 4304  053EC310-A41C-ED11-B83E-002248DE66D4  SAUDE E SEGURANCA NA INDUSTRIA
#
#                         Produto GPOM Data de Venda    Cidade  \
# 468     APERFEICOAMENTO PROFISSIONAL    2022-09-13  CURITIBA
# 2156             AUXILIO DIAGNOSTICO    2022-08-25  CURITIBA
# ...
